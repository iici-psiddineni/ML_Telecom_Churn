# %%
import os.path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
# Load clean telecom data file
master_df = pd.read_csv('telecom_churn_data_clean.csv', low_memory=False)

# %%
master_df.head()
# Out:
#    mobile_number  arpu_6  arpu_7  arpu_8  onnet_mou_6  onnet_mou_7  \
# 0     7000701601 1069.18 1349.85 3171.48        57.84        54.68
# 1     7001524846  378.72  492.22  137.36       413.69       351.03
# 2     7002191713  492.85  205.67  593.26       501.76       108.39
# 3     7000875565  430.98  299.87  187.89        50.51        74.01
# 4     7000187447  690.01   18.98   25.50      1185.91         9.28
#
#    onnet_mou_8  offnet_mou_6  offnet_mou_7  offnet_mou_8  ...    sachet_3g_7  \
# 0        52.29        453.43        567.16        325.91  ...              0
# 1        35.08         94.66         80.63        136.48  ...              0
# 2       534.24        413.31        119.28        482.46  ...              0
# 3        70.61        296.29        229.74        162.76  ...              0
# 4         7.79         61.64          0.00          5.54  ...              0
#
#    sachet_3g_8   aon  aug_vbc_3g  jul_vbc_3g  jun_vbc_3g  rech_days_left_6  \
# ...

# %%
# Splitting the data into train and test
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import f_classif
X = master_df.drop(['churn'],axis=1)
y = master_df['churn']
feature=X.columns
selector_f= SelectPercentile(f_classif,percentile=25)
selector_f.fit(X,y)
print(len(selector_f.scores_))
for n,s in zip (feature,selector_f.scores_):
    print("importance of for feature %s",(s,n))
# Out:
# 128
# importance of for feature %s (21.562849765044376, 'mobile_number')
# importance of for feature %s (27.48268710185094, 'arpu_6')
# importance of for feature %s (3.327429914940888, 'arpu_7')
# importance of for feature %s (414.8800944351591, 'arpu_8')
# importance of for feature %s (170.32544957116025, 'onnet_mou_6')
# importance of for feature %s (44.682124712631406, 'onnet_mou_7')
# importance of for feature %s (104.31850330704793, 'onnet_mou_8')
# importance of for feature %s (75.50308035892749, 'offnet_mou_6')
# importance of for feature %s (22.440761322801706, 'offnet_mou_7')
# importance of for feature %s (269.8136559773753, 'offnet_mou_8')
# importance of for feature %s (77.62301149663739, 'roam_ic_mou_6')
# importance of for feature %s (194.89088755208292, 'roam_ic_mou_7')
# importance of for feature %s (224.5894130548647, 'roam_ic_mou_8')
# importance of for feature %s (122.3367755246841, 'roam_og_mou_6')
# ...

# %%
print(X.shape)
# Out:
# (28861, 128)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
X_tr,y_tr = sm.fit_sample(X,y)
print(X_tr.shape)
print(y_tr.shape)
np.count_nonzero(y_tr)
# Out:
# (54108, 128)
# (54108,)
# 27054

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tr,y_tr, train_size=0.7,test_size=0.3,random_state=100)
print(X_train.shape)
# Out:
# (37875, 128)
